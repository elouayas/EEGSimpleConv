# %% [markdown]
# # Cross-Subject on BNCI

# %%
from scripts.scripts import *


p          = [109,4,70,8] 
dict_config = { 
'model':'EEGSimpleConv',
'params':p,
'dataset':'BNCI',
'runs':5,
'n_epochs':50,
'EA':True,
'mixup':True,
'BN':True,
'EOG':False,
'Z':'Z0',
'path':'/users/local/simpleconv_datasets',
'lmso':False,
'session':True,
'reg_subject':False,
'use_wandb':False,
'evaluation':'cross',
'comment':'baseline',
'within':False,
'mdl':False,
'filter':0.5,
'save_model':False,
'load_model':False,
'preload_reg':False,
'online':False
}
    
    
X,Y = load_data(dict_config)
best_params = dict_config['params']
best_score = train_test(best_params,dict_config, X,Y)
# Out:
# [109, 4, 70, 8, 22, 4, 250] 2462246 params
# Split: 0
#  49 test: 0.759
#  49 test: 0.792
#  49 test: 0.773
#  49 test: 0.780
#  49 test: 0.778  average: 0.776
# Split: 1
#  49 test: 0.545
#  49 test: 0.576
#  49 test: 0.583
#  49 test: 0.575
#  49 test: 0.576  average: 0.571
# Split: 2
#  49 test: 0.811
#  49 test: 0.826
#  49 test: 0.806
#  49 test: 0.828
#  49 test: 0.837  average: 0.822
# Split: 3
#  49 test: 0.653
#  49 test: 0.661
#  49 test: 0.637
#  49 test: 0.639
#  49 test: 0.632  average: 0.644
# Split: 4
#  49 test: 0.691
#  49 test: 0.672
#  49 test: 0.646
#  49 test: 0.675
#  49 test: 0.653  average: 0.667
# Split: 5
#  49 test: 0.667
#  49 test: 0.655
#  49 test: 0.632
#  49 test: 0.655
#  49 test: 0.637  average: 0.649
# Split: 6
#  49 test: 0.694
#  49 test: 0.743
#  49 test: 0.701
#  49 test: 0.717
#  49 test: 0.719  average: 0.715
# Split: 7
#  49 test: 0.750
#  49 test: 0.753
#  49 test: 0.729
#  49 test: 0.710
#  49 test: 0.748  average: 0.738
# Split: 8
#  49 test: 0.727
#  49 test: 0.762
#  49 test: 0.727
#  49 test: 0.757
#  49 test: 0.701  average: 0.735
# 0.702

# %% [markdown]
# # Cross-Subject on BNCI with subject-wise reguralization

# %%
from scripts.scripts import *


p          = [0.18,163,4,55,5]
dict_config = { 
'model':'EEGSimpleConv',
'params':p,
'dataset':'BNCI',
'runs':5,
'n_epochs':50,
'EA':True,
'mixup':True,
'BN':True,
'EOG':False,
'Z':'Z0',
'path':'/users/local/simpleconv_datasets',
'lmso':False,
'session':True,
'reg_subject':True,
'use_wandb':False,
'evaluation':'cross',
'comment':'baseline',
'within':False,
'mdl':False,
'filter':0.5,
'save_model':False,
'load_model':False,
'preload_reg':False,
'online':False
}    
    
    
X,Y = load_data(dict_config)
best_params = dict_config['params']
best_score = train_test(best_params,dict_config, X,Y)
# Out:
# [0.18, 163, 4, 55, 5, 22, 4, 250, 9] 3447739 params
# Split: 0
#  49 test: 0.773
#  49 test: 0.799
#  49 test: 0.799
#  49 test: 0.811
#  49 test: 0.814  average: 0.799
# Split: 1
#  49 test: 0.556
#  49 test: 0.559
#  49 test: 0.552
#  49 test: 0.533
#  49 test: 0.583  average: 0.557
# Split: 2
#  49 test: 0.826
#  49 test: 0.818
#  49 test: 0.837
#  49 test: 0.821
#  49 test: 0.828  average: 0.826
# Split: 3
#  49 test: 0.637
#  49 test: 0.628
#  49 test: 0.658
#  49 test: 0.675
#  49 test: 0.653  average: 0.650
# Split: 4
#  49 test: 0.649
#  49 test: 0.682
#  49 test: 0.675
#  49 test: 0.655
#  49 test: 0.682  average: 0.669
# Split: 5
#  49 test: 0.675
#  49 test: 0.665
#  49 test: 0.670
#  49 test: 0.658
#  49 test: 0.672  average: 0.668
# Split: 6
#  49 test: 0.736
#  49 test: 0.729
#  49 test: 0.717
#  49 test: 0.708
#  49 test: 0.712  average: 0.720
# Split: 7
#  49 test: 0.748
#  49 test: 0.745
#  49 test: 0.747
#  49 test: 0.762
#  49 test: 0.714  average: 0.743
# Split: 8
#  49 test: 0.689
#  49 test: 0.759
#  49 test: 0.705
#  49 test: 0.733
#  49 test: 0.726  average: 0.722
# 0.706

# %% [markdown]
# # Within-Subject on BNCI

# %%
from scripts.scripts import *


p          = [84,1,95,13]
dict_config = { 
'model':'EEGSimpleConv',
'params':p,
'dataset':'BNCI',
'runs':5,
'n_epochs':50,
'EA':True,
'mixup':True,
'BN':True,
'EOG':False,
'Z':'Z0',
'path':'/users/local/simpleconv_datasets',
'lmso':False,
'session':True,
'reg_subject':False,
'use_wandb':False,
'evaluation':'within',
'comment':'baseline',
'within':True,
'mdl':False,
'filter':0.5,
'save_model':False,
'load_model':False,
'preload_reg':False,
'online':False
}  
    
    
X,Y = load_data(dict_config)
best_params = dict_config['params']
best_score = train_test(best_params,dict_config, X,Y)
# Out:
# [84, 1, 95, 13, 22, 4, 250] 208324 params
# Split: 0
#  49 test: 0.830
#  49 test: 0.799
#  49 test: 0.816
#  49 test: 0.826
#  49 test: 0.812  average: 0.817
# Split: 1
#  49 test: 0.559
#  49 test: 0.559
#  49 test: 0.583
#  49 test: 0.556
#  49 test: 0.576  average: 0.567
# Split: 2
#  49 test: 0.885
#  49 test: 0.872
#  49 test: 0.892
#  49 test: 0.882
#  49 test: 0.906  average: 0.887
# Split: 3
#  49 test: 0.688
#  49 test: 0.767
#  49 test: 0.740
#  49 test: 0.740
#  49 test: 0.726  average: 0.732
# Split: 4
#  49 test: 0.639
#  49 test: 0.611
#  49 test: 0.688
#  49 test: 0.615
#  49 test: 0.635  average: 0.637
# Split: 5
#  49 test: 0.681
#  49 test: 0.660
#  49 test: 0.656
#  49 test: 0.660
#  49 test: 0.646  average: 0.660
# Split: 6
#  49 test: 0.885
#  49 test: 0.872
#  49 test: 0.885
#  49 test: 0.889
#  49 test: 0.892  average: 0.885
# Split: 7
#  49 test: 0.851
#  49 test: 0.837
#  49 test: 0.872
#  49 test: 0.882
#  49 test: 0.851  average: 0.858
# Split: 8
#  49 test: 0.819
#  49 test: 0.795
#  49 test: 0.819
#  49 test: 0.823
#  49 test: 0.795  average: 0.810
# 0.762

# %% [markdown]
# # Cross-Subject with Fine-Tuning on BNCI
#
# To run the following cell run the second code cell (Cross-Subject on BNCI with subject-wise reguralization first) with the argument save_model = True in its dict_config. It will provide the required pretrained model for each subject and each run.

# %%
from scripts.scripts import *


p          = [163,4,55,5]
dict_config = { 
'model':'EEGSimpleConv',
'params':p,
'dataset':'BNCI',
'runs':5,
'n_epochs':50,
'EA':True,
'mixup':True,
'BN':True,
'EOG':False,
'Z':'Z0',
'path':'/users/local/simpleconv_datasets',
'lmso':False,
'session':True,
'reg_subject':False,
'use_wandb':False,
'evaluation':'cross_finetune',
'comment':'baseline',
'within':True,
'mdl':False,
'filter':0.5,
'save_model':False,
'load_model':True,
'preload_reg':True,
'online':False
}

    
    
    
X,Y = load_data(dict_config)
best_params = dict_config['params']
best_score = train_test(best_params,dict_config, X,Y)
# Out:
# Sampling Freq: 250
# [163, 4, 55, 5, 22, 4, 250] 3447739 params
# Split: 0
#  49 test: 0.840
#  49 test: 0.840
#  49 test: 0.861
#  49 test: 0.868
#  49 test: 0.833  average: 0.849
# Split: 1
#  49 test: 0.681
#  49 test: 0.684
#  49 test: 0.726
#  49 test: 0.712
#  49 test: 0.736  average: 0.708
# Split: 2
#  49 test: 0.958
#  49 test: 0.948
#  49 test: 0.920
#  49 test: 0.931
#  49 test: 0.913  average: 0.934
# Split: 3
#  49 test: 0.896
#  49 test: 0.889
#  49 test: 0.885
#  49 test: 0.899
#  49 test: 0.868  average: 0.887
# Split: 4
#  49 test: 0.771
#  49 test: 0.806
#  49 test: 0.774
#  49 test: 0.802
#  49 test: 0.812  average: 0.793
# Split: 5
#  49 test: 0.771
#  49 test: 0.792
#  49 test: 0.812
#  49 test: 0.819
#  49 test: 0.753  average: 0.790
# Split: 6
#  49 test: 0.903
#  49 test: 0.899
#  49 test: 0.889
#  49 test: 0.917
#  49 test: 0.885  average: 0.899
# Split: 7
#  49 test: 0.885
#  49 test: 0.865
#  49 test: 0.875
#  49 test: 0.847
#  49 test: 0.882  average: 0.871
# Split: 8
#  49 test: 0.882
#  49 test: 0.858
#  49 test: 0.830
#  49 test: 0.844
#  49 test: 0.851  average: 0.853
# 0.843
